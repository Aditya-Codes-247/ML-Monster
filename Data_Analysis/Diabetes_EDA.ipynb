# %% [markdown]
# Imports

# %%
from sklearn.datasets import load_diabetes
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# %% [markdown]
# Loading Dataset

# %%
diabetes = load_diabetes()
X = diabetes.data 
y = diabetes.target
df = pd.DataFrame(X,columns=diabetes.feature_names)
df['target'] = y

# %% [markdown]
# Initial Inspection

# %%
print("First few rows of the dataset: ")
print(df.head)
# Out:
# First few rows of the dataset:
# <bound method NDFrame.head of           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019907 -0.017646   151.0
# 1   -0.039493 -0.068332 -0.092204    75.0
# 2   -0.002592  0.002861 -0.025930   141.0
# 3    0.034309  0.022688 -0.009362   206.0
# 4   -0.002592 -0.031988 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]>

# %%
print("Basic info. about the dataset: ")
print(df.info)
# Out:
# Basic info. about the dataset:
# <bound method DataFrame.info of           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019907 -0.017646   151.0
# 1   -0.039493 -0.068332 -0.092204    75.0
# 2   -0.002592  0.002861 -0.025930   141.0
# 3    0.034309  0.022688 -0.009362   206.0
# 4   -0.002592 -0.031988 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]>

# %% [markdown]
# Discriptive Analysis

# %%
print("Statistical Description of the dataset: ")
print(df.describe)
# Out:
# Statistical Description of the dataset:
# <bound method NDFrame.describe of           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019907 -0.017646   151.0
# 1   -0.039493 -0.068332 -0.092204    75.0
# 2   -0.002592  0.002861 -0.025930   141.0
# 3    0.034309  0.022688 -0.009362   206.0
# 4   -0.002592 -0.031988 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018114  0.044485   104.0
# 439 -0.011080 -0.046883  0.015491   132.0
# 440  0.026560  0.044529 -0.025930   220.0
# 441 -0.039493 -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]>

# %%
print("Missing Values: ")
print(df.isnull().sum())
# Out:
# Missing Values:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %% [markdown]
# Exploratory Analysis

# %%
# Histplot
print("Column Names: ")
print(df.columns)
for i in df.columns: 
    plt.figure(figsize=(3,3))
    sns.histplot(df[i],kde =True,bins=30)
    plt.title(f'{i} Distribution')
    plt.show()
# Out:
# Column Names:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %%
# Count Plot
print(df.columns)
for i in df.columns:
    plt.figure(figsize=(4,4))
    sns.countplot(x = df[i],hue=df['target'],data=df)
    plt.title(f"Count plot for {i}")
    plt.show()
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %%
# Heatmap
print(df.columns)
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %% [markdown]
# Inferential Analysis

# %%
print(df.columns)
for i in df.columns[0:10]:
    feature = i
    group1 = df[df[feature]>df[feature].median()]['target']
    group2 = df[df[feature]<=df[feature].median()]['target']

    t_stat,p_value = stats.ttest_ind(group1,group2)
    print(f'T stat. value for {i} against target is {t_stat}')
    print(f'P value for {i} against target is {p_value}')
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')
# T stat. value for age against target is 4.21220577589702
# P value for age against target is 3.069012496062111e-05
# T stat. value for sex against target is 0.9041147550244715
# P value for sex against target is 0.3664292946519826
# T stat. value for bmi against target is 12.307227162148363
# P value for bmi against target is 4.052305553278657e-30
# T stat. value for bp against target is 7.740729755097035
# P value for bp against target is 6.845150153816298e-14
# T stat. value for s1 against target is 3.9806066267646045
# P value for s1 against target is 8.039570972439356e-05
# T stat. value for s2 against target is 2.7784233086459715
# P value for s2 against target is 0.005696082979625167
# T stat. value for s3 against target is -7.473152438875541
# P value for s3 against target is 4.2620213594917576e-13
# T stat. value for s4 against target is 7.558735670434464
# P value for s4 against target is 2.38684261657201e-13
# T stat. value for s5 against target is 13.13000263461442
# P value for s5 against target is 1.841058480232512e-33
# T stat. value for s6 against target is 5.063339229696086
# P value for s6 against target is 6.06922309065239e-07
